# %% [markdown]
# # Passo 6 — Figuras para o artigo
#
# Figuras em `paper/ieee/figures/` (e cópia em `classification/figures/`).
#
# Reexecutar: `python ../scripts/run_passo6.py`
#
# | Arquivo | Conteúdo |
# |---------|----------|
# | `fig_schema_lpg_fbg.png` | Esquema LPFG + 13 FBGs + máscara |
# | `fig_mask_true_vs_pred.png` | Exemplo real true vs SVM |
# | `fig_metrics_classifiers.png` | Barras de métricas |
# | `fig_error_heatmap_fbg.png` | Heatmap de erro por FBG |
# | `fig_jaccard_vs_lambda.png` | Jaccard vs $\lambda_{res}$ |
#
# ROC/PR por canal: opcional, não gerado.

# %%
from pathlib import Path
from IPython.display import Image, display

IEEE = Path("../../ieee/figures")
for name in [
    "fig_schema_lpg_fbg.png",
    "fig_mask_true_vs_pred.png",
    "fig_metrics_classifiers.png",
    "fig_error_heatmap_fbg.png",
    "fig_jaccard_vs_lambda.png",
]:
    p = IEEE / name
    print(p)
    display(Image(filename=str(p), width=520))
