# %% [markdown]
# # Passo 5 — Métricas e análise
#
# Modelos com hiperparâmetros de consenso do Passo 4; CV estratégia A; hold-out intacto.
#
# Reexecutar: `python ../scripts/run_passo5.py`

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path("..").resolve()
sys.path.insert(0, str(ROOT))
from src.data_utils import RESULTS_DIR, FIGURES_DIR

print("Figuras em", FIGURES_DIR)
pd.read_csv(RESULTS_DIR / "passo5_summary_k4.csv")

# %%
display(pd.read_csv(RESULTS_DIR / "passo5_compare_k.csv").pivot(
    index="classifier", columns="k", values="jaccard_mean"
).round(4))
display(pd.read_csv(RESULTS_DIR / "passo5_feature_delta.csv").round(4))
